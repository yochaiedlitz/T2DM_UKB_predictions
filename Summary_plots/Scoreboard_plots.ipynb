# %%
from imports import *
from Article_files.UKBB_article_plots_functions import *
# Out:
# dropped the following lines due to duplicated indexes:
# Empty DataFrame
# Columns: [Label]
# Index: []
# ('A dataframe with the dropped columns was saved to: ', '/home/edlitzy/UKBB_Tree_Runs/For_article/dropped_UKBIOBANK_Labels.csv')

# %%
tmp_dict,tmp_df=upload_ukbb_dict()

# %%
print(tmp_df)
# Out:
#                                                                         Label
# Code
# 31-0.0_1.0                                                               Male
# 30040-0.0                                             Mean corpuscular volume
# 30270-0.0                                            Mean sphered cell volume
# 20110-0.0_8.0                                   High blood pressure of mother
# 30160-0.0                                                     Basophill count
# 30660-0.0                                                    Direct bilirubin
# 20110-0.0_-17.0                                 Mother's illness - not listed
# 20022-0.0                                                        Birth weight
# 30780-0.0                                                          LDL direct
# 21003-4.0                                                 Time between visits
# 30800-0.0                                                          Oestradiol
# ...

# %%
df=pd.read_csv("~/UKBB_Tree_Runs/For_article/Imputed_screened_CI_Summary.csv",index_col="File name")

# %%
df
# Out:
#                                                                                   Label  \
# File name
# LR_Strat_L39_Five_Blood_Tests                        Five blood tests 5.7<HbA1c%<6.5 LR
# LR_Strat_L20_H39_Blood_tests                             Blood tests 4.5< HbA1c%<5.7 LR
# LR_A1c_Strat_high_All_No_A1c_No_Gluc  All features w/o HbA1c% nor Glucose 5.7<HbA1c%...
# LR_Strat_L39_Blood_tests                                  Blood tests 5.7<HbA1c%<6.5 LR
# LR_A1c_Strat_low_All_No_A1c_No_Gluc   HbA1c% Strat low all features No HbA1c% No Glu...
# LR_Strat_L20_H39_Finrisc                                    FINDRISC 4.5< HbA1c%<5.7 LR
# Strat_L20_H39_Antro_neto_whr                  Anthropometry with WHR 4.5< HbA1c%<5.7 DT
# SA_Strat_L39_GDRS                                                GDRS 5.7<HbA1c%<6.5 SA
# SA_Strat_L20_H39_GDRS                                          GDRS 4.5< HbA1c%<5.7  SA
# ...

# %%
df.index
# Out:
# Index([u'LR_Strat_L39_Five_Blood_Tests', u'LR_Strat_L20_H39_Blood_tests',
#        u'LR_A1c_Strat_high_All_No_A1c_No_Gluc', u'LR_Strat_L39_Blood_tests',
#        u'LR_A1c_Strat_low_All_No_A1c_No_Gluc', u'LR_Strat_L20_H39_Finrisc',
#        u'Strat_L20_H39_Antro_neto_whr', u'SA_Strat_L39_GDRS',
#        u'SA_Strat_L20_H39_GDRS', u'LR_Strat_L39_Finrisc',
#        u'LR_Strat_L20_H39_Five_Blood_Tests', u'A9_Diet__Family',
#        u'A8_Medication__Diet', u'A10_Family__ELF', u'A5_BP_n_HR__ND_Diagnosis',
#        u'A4_Lifestyle__BP_n_HR', u'A3_Physical_Health__Lifestyle', u'All',
#        u'A11_ELF__Socio', u'A6_ND_Diagnosis__Mental',
#        u'A2_Anthro__Physical_Health', u'A1_BT__Anthro',
#        u'A7_Mental__Medication', u'Anthropometry', u'All_No_A1c_No_Gluc',
#        u'Physical_health', u'Family_and_Ethnicity', u'Medication',
#        u'Genetics_Age_and_Sex', u'BT_No_A1c_No_Gluc',
#        u'Lifestyle_and_physical_activity', u'Only_genetics', u'Age_and_Sex',
# ...

# %%
exp=[x for x in df.index if "explore" in x]

# %%
exp
# Out:
# []

# %%
df
# Out:
#                                                                                   Label  \
# File name
# LR_Strat_L39_Five_Blood_Tests                        Five blood tests 5.7<HbA1c%<6.5 LR
# LR_Strat_L20_H39_Blood_tests                             Blood tests 4.5< HbA1c%<5.7 LR
# LR_A1c_Strat_high_All_No_A1c_No_Gluc  All features w/o HbA1c% nor Glucose 5.7<HbA1c%...
# LR_Strat_L39_Blood_tests                                  Blood tests 5.7<HbA1c%<6.5 LR
# LR_A1c_Strat_low_All_No_A1c_No_Gluc   HbA1c% Strat low all features No HbA1c% No Glu...
# LR_Strat_L20_H39_Finrisc                                    FINDRISC 4.5< HbA1c%<5.7 LR
# Strat_L20_H39_Antro_neto_whr                  Anthropometry with WHR 4.5< HbA1c%<5.7 DT
# SA_Strat_L39_GDRS                                                GDRS 5.7<HbA1c%<6.5 SA
# SA_Strat_L20_H39_GDRS                                          GDRS 4.5< HbA1c%<5.7  SA
# ...
